# %%
import numpy as np
import pandas as pd  
import tensorflow as tf
import sklearn

# %%
df = pd.read_excel (r'D:\Dlamini\Maize Extracted_data.xls')

# %%
df.head(65)
# Out:
#      LAI        FMC         EWT    DMC        SLA1      SLA2      SLA3  \
# 0   2.93  80.889973  274.312410  26.54  154.307815  0.015431  0.467305
# 1   2.00  79.024390  229.421136   6.48  164.215116  0.016422  1.162791
# 2   1.20  82.250471  291.399787  17.47  159.023873  0.015902  0.318302
# 3   1.52  83.856749  274.224352  15.22  189.426621  0.018943  0.518771
# 4   1.35  81.795968  252.989967  13.39  177.607383  0.017761  0.453020
# ..   ...        ...         ...    ...         ...       ...       ...
# 57  2.26  80.381879  249.627942  21.47  164.137405  0.016414  0.431298
# 58  2.07  81.337047  275.937016  23.36  157.942164  0.015794  0.386194
# 59  1.78  83.074189  208.637829  18.70  235.246719  0.023525  0.467192
# 60  1.62  80.111684  219.843693  18.65  183.224622  0.018322  0.349892
# 61  1.44  81.279519  241.561922  18.93  179.736239  0.017974  0.330275
#
#         Blue     Green       Red  ...  CIrededge       CVI       GLI  \
# ...

# %%
# !pip install keras
# Out:
# ...
#      ---------------------------------------- 1.7/1.7 MB 6.9 MB/s eta 0:00:00
# ...

# %%
# !pip install xlrd
# Out:
# ...
#      ---------------------------------------- 96.5/96.5 kB 1.4 MB/s eta 0:00:00
# ...

# %%
# !pip install tensorflow

# %%
X = df.iloc[:, 13:].values 
y = df.iloc[:,0].values

# %%
from sklearn.model_selection  import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, random_state = 0)

# %%
#machine learning stuff

#NEURAL NETWORK - Keras will be updated soon so this colab will also have to be changed
from sklearn.neural_network import MLPRegressor as ANN_reg #this is a simpler neural network package
from keras.models import Sequential
from keras.layers import Dense
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
#ignore the warning for now

#Architecture of the ANN to be used in the model
# We use two hidden layers with six hidden neurons each
#sequence of layers, and computational graph- ANN
ann = tf.keras.models.Sequential()
#add input layer and first hidden layer
ann.add(tf.keras.layers.Dense(units=6, activation='relu')) #1st hidden layer
ann.add(tf.keras.layers.Dense(units=6, activation='relu')) #2nd hidden layer
ann.add(tf.keras.layers.Dense(units=6, activation='relu')) #3rd hidden layer
ann.add(tf.keras.layers.Dense(units=6, activation='relu')) #4th hidden layer
#ann.add(tf.keras.layers.Dense(units=6, activation='relu')) #5th hidden layer
#ann.add(tf.keras.layers.Dense(units=6, activation='relu')) #6th hidden layer
#add last output layer
ann.add(tf.keras.layers.Dense(units=1)) #unit parameter is the number of neurons

# %%
#Part 5: Training the ANN
#compile the ANN with a loss function and an optimizer##The optimizer adjusts teh weights in the neurons to decrease error
#Compile the ANN
ann.compile(optimizer= 'adam', loss = 'mean_squared_error')
ann.fit(X_train, y_train, batch_size = 32, epochs = 500)#batch_size= sets of features being forwadly propagated, essenstilaluy in groups.
# Out:
# Train on 43 samples
# Epoch 1/500
# 43/43 [==============================] - 4s 89ms/sample - loss: 0.1480
# Epoch 2/500
# 43/43 [==============================] - 0s 209us/sample - loss: 0.1503
# Epoch 3/500
# 43/43 [==============================] - 0s 302us/sample - loss: 0.1476
# Epoch 4/500
# 43/43 [==============================] - 0s 581us/sample - loss: 0.1481
# Epoch 5/500
# 43/43 [==============================] - 0s 767us/sample - loss: 0.1496
# Epoch 6/500
# 43/43 [==============================] - 0s 814us/sample - loss: 0.1496
# Epoch 7/500
# 43/43 [==============================] - 0s 1ms/sample - loss: 0.1480
# Epoch 8/500
# 43/43 [==============================] - 0s 697us/sample - loss: 0.1467
# Epoch 9/500
# 43/43 [==============================] - 0s 651us/sample - loss: 0.1467
# Epoch 10/500
# 43/43 [==============================] - 0s 605us/sample - loss: 0.1468
# Epoch 11/500
# 43/43 [==============================] - 0s 767us/sample - loss: 0.1476
# ...

# %%
y_pred = ann.predict(X_train)
from sklearn import metrics
r_square_ann = metrics.r2_score(y_train, y_pred)
print('r-square: ', r_square_ann)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\keras\engine\training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# r-square:  0.1582596927795883

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
#Part 5: Test the dataset
#compile the ANN with a loss function and an optimizer##The optimizer adjusts teh weights in the neurons to decrease error
#Compile the ANN
ann.compile(optimizer= 'adam', loss = 'mean_squared_error')
ann.fit(X_test, y_test, batch_size = 32, epochs = 500)#batch_size= sets of features being forwadly propagated, essenstilaluy in groups.
# Out:
# Train on 19 samples
# Epoch 1/500
# 19/19 [==============================] - 9s 459ms/sample - loss: 0.0958
# Epoch 2/500
# 19/19 [==============================] - 0s 2ms/sample - loss: 0.0907
# Epoch 3/500
# 19/19 [==============================] - 0s 3ms/sample - loss: 0.0876
# Epoch 4/500
# 19/19 [==============================] - 0s 3ms/sample - loss: 0.0846
# Epoch 5/500
# 19/19 [==============================] - 0s 2ms/sample - loss: 0.0816
# Epoch 6/500
# 19/19 [==============================] - 0s 3ms/sample - loss: 0.0786
# Epoch 7/500
# 19/19 [==============================] - 0s 2ms/sample - loss: 0.0754
# Epoch 8/500
# 19/19 [==============================] - 0s 1ms/sample - loss: 0.0727
# Epoch 9/500
# 19/19 [==============================] - 0s 2ms/sample - loss: 0.0707
# Epoch 10/500
# 19/19 [==============================] - 0s 3ms/sample - loss: 0.0694
# Epoch 11/500
# 19/19 [==============================] - 0s 3ms/sample - loss: 0.0682
# Epoch 12/500
# ...

# %%
y_pred = ann.predict(X_test)
from sklearn import metrics
r_square_ann = metrics.r2_score(y_test, y_pred)
print('r-square: ', r_square_ann)
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\keras\engine\training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# r-square:  0.7669519106765108
